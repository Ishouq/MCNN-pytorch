# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishouq/MCNN-pytorch/blob/main/TEST2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !git clone https://github.com/Ishouq/MCNN-pytorch.git
# Out:
# fatal: destination path 'MCNN-pytorch' already exists and is not an empty directory.

# %%
pip show scipy
# Out:
# Name: scipy
# Version: 1.7.3
# Summary: SciPy: Scientific Library for Python
# Home-page: https://www.scipy.org
# Author: None
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: numpy
# Required-by: yellowbrick, xgboost, xarray-einstats, statsmodels, sklearn-pandas, seaborn, scs, scikit-learn, scikit-image, qdldl, pymc, plotnine, osqp, mlxtend, missingno, matplotlib-venn, lightgbm, librosa, jaxlib, jax, imgaug, imbalanced-learn, hyperopt, gensim, fastai, fa2, ecos, datascience, cvxpy, arviz, albumentations, aesara, aeppl

# %%
pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install visdom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m visdom.server
# Out:
# Checking for scripts.
# It's Alive!
# ERROR:root:initializing
# INFO:root:Application Started
# INFO:root:Working directory: /root/.visdom
# You can navigate to http://60af406de94a:8097

# %%
# !python /content/MCNN-pytorch/data_preparation/k_nearest_gaussian_kernel.py
# Out:
# /content/drive/MyDrive/ShanghaiTech/part_A/train_data/images/IMG_119.jpg
# Shape of current image:  [594, 1024] . Totally need generate  216 gaussian kernels.
# generate density...
# done.
# /content/drive/MyDrive/ShanghaiTech/part_A/train_data/images/IMG_116.jpg
# Shape of current image:  [640, 640] . Totally need generate  614 gaussian kernels.
# generate density...
# done.
# /content/drive/MyDrive/ShanghaiTech/part_A/train_data/images/IMG_120.jpg
# Shape of current image:  [768, 1024] . Totally need generate  2261 gaussian kernels.
# generate density...
# done.
# /content/drive/MyDrive/ShanghaiTech/part_A/train_data/images/IMG_11.jpg
# Shape of current image:  [686, 1024] . Totally need generate  248 gaussian kernels.
# generate density...
# done.
# /content/drive/MyDrive/ShanghaiTech/part_A/train_data/images/IMG_103.jpg
# Shape of current image:  [400, 400] . Totally need generate  43 gaussian kernels.
# generate density...
# done.
# ...

# %%
# !git config --global user.name "Ishouq"
# !git config --global user.email "shouq.alsalmi@gmail.com"
# !git config --global user.password "Shouq@1995"
